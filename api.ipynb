# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.energy-charts.info/price?country=uk')

# %%
pd.DataFrame(response.json()).head(4)
# Out:
#                                         license_info  unix_seconds   price  \
# 0  CC BY 4.0 (creativecommons.org/licenses/by/4.0...    1776290400  112.51
# 1  CC BY 4.0 (creativecommons.org/licenses/by/4.0...    1776291300  108.71
# 2  CC BY 4.0 (creativecommons.org/licenses/by/4.0...    1776292200  103.53
# 3  CC BY 4.0 (creativecommons.org/licenses/by/4.0...    1776293100  100.11
#
#         unit  deprecated
# 0  EUR / MWh       False
# 1  EUR / MWh       False
# 2  EUR / MWh       False
# 3  EUR / MWh       False

# %%
response1 = requests.get('https://api.weatherapi.com/v1/history.json?key=75d6551c4a7a4cdfb43102252261604&q=Thiruvananthapuram&dt=2024-01-01')
response1['location']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 response1 = requests.get('https://api.weatherapi.com/v1/history.json?key=75d6551c4a7a4cdfb43102252261604&q=Thiruvananthapuram&dt=2024-01-01')
# ----> 2 response1['location']
#
# TypeError: 'Response' object is not subscriptable
